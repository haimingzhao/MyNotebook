# %%
import imp
hdf5_getters = imp.load_source('hdf5_getters', '/Users/mira/MSD/hdf5_getters.py')
h5 = hdf5_getters.open_h5_file_read('/Users/mira/MSD/msd_summary_file.h5')

# %%
h5.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a70de5b9551f> in <module>()
# ----> 1 h5.shape
#
# AttributeError: 'File' object has no attribute 'shape'

# %%
for k in range(1000000):
    s = h5.root.metadata.songs.cols.genre[k]
    print s
